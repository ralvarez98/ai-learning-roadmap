# %% [markdown]
# # 📘 Day 07 – Normalización, Escalado y Regresión Lineal
# **Objetivo:** Aprender a escalar datos numéricos y aplicar una regresión lineal para análisis predictivo y exploratorio.

# %%
# Paso 1: Importación de librerías necesarias
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
sns.set(style='whitegrid')

# %%
# Paso 2: Crear un DataFrame simulado
np.random.seed(42)
data = {
    'años_experiencia': np.random.randint(1, 11, 20),
    'salario_mensual': np.random.randint(15000, 50000, 20)
}
df = pd.DataFrame(data)
df.head()
# Out:
#    años_experiencia  salario_mensual
# 0                 7            20311
# 1                 4            32568
# 2                 8            34769
# 3                 5            43693
# 4                 7            21396

# %%
# Paso 3: Normalización con MinMaxScaler
scaler = MinMaxScaler()
df[['años_experiencia', 'salario_mensual']] = scaler.fit_transform(df[['años_experiencia', 'salario_mensual']])
df.head()
# Out:
#    años_experiencia  salario_mensual
# 0             0.625         0.163319
# 1             0.250         0.554142
# 2             0.750         0.624322
# 3             0.375         0.908871
# 4             0.625         0.197915

# %%
# Paso 4: Visualización de correlaciones
sns.heatmap(df.corr(), annot=True, cmap='Blues')
plt.title('Matriz de correlación')
plt.show()

# %%
# Paso 5: Entrenamiento de modelo de regresión lineal
x = df[['años_experiencia']]  # Variable independiente
y = df['salario_mensual']     # Variable dependiente
modelo = LinearRegression()   # Crear modelo
modelo.fit(x, y)              # Entrenar modelo
y_pred = modelo.predict(X)
r2 = r2_score(y, y_pred)
print(f"Coeficiente: {modelo.coef_[0]:.2f}")
print(f"Intersección: {modelo.intercept_:.2f}")
print(f"R² Score: {r2:.2f}")
# Out:
# Coeficiente: 0.24
# Intersección: 0.34
# R² Score: 0.04

# %%
# Paso 6: Visualización del modelo
plt.figure(figsize=(8, 5))
sns.scatterplot(x='años_experiencia', y='salario_mensual', data=df, label='Datos reales')
plt.plot(df['años_experiencia'], y_pred, color='red', label='Regresión lineal')
plt.legend()
plt.title('Regresión lineal: experiencia vs salario')
plt.show()

# %% [markdown]
# 🧪 Mini práctica Día 7: Predicción del Salario según la Experiencia
# Contexto:
# Imagina que estás colaborando con el área de Recursos Humanos de una empresa tecnológica. Te piden analizar los datos de empleados y desarrollar un modelo que prediga el salario mensual con base en los años de experiencia de un candidato.

# %%
# Paso 1: Importación de librerías
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

sns.set(style='whitegrid')

# Paso 2: Crear un DataFrame simulado (como si fueran datos de empleados)
np.random.seed(42)
data = {
    'años_experiencia': np.random.randint(1, 11, 50),
    'salario_mensual': np.random.randint(15000, 50000, 50)
}
df = pd.DataFrame(data)
df.head()

# Paso 3: Normalización con MinMaxScaler
scaler = MinMaxScaler()
df[['años_experiencia', 'salario_mensual']] = scaler.fit_transform(df[['años_experiencia', 'salario_mensual']])
df.head()

# Paso 4: Visualización de correlaciones
plt.figure(figsize=(5, 4))
sns.heatmap(df.corr(), annot=True, cmap='Blues')
plt.title('Matriz de correlación')
plt.show()

# Paso 5: Entrenamiento del modelo
x = df[['años_experiencia']]
y = df['salario_mensual']
modelo = LinearRegression()
modelo.fit(x, y)

# Paso 6: Predicción y creación de nueva columna
df['salario_predicho'] = modelo.predict(x)

# Paso 7: Evaluación del modelo
r2 = r2_score(y, df['salario_predicho'])
print(f"🔎 R² Score del modelo: {r2:.4f}")

# Paso 8: Visualización del modelo entrenado
plt.figure(figsize=(7, 4))
sns.scatterplot(x='años_experiencia', y='salario_mensual', data=df, label='Real')
sns.lineplot(x='años_experiencia', y='salario_predicho', data=df, color='red', label='Modelo Lineal')
plt.title('Regresión Lineal: Salario vs Años de Experiencia')
plt.xlabel('Años de Experiencia (normalizado)')
plt.ylabel('Salario Mensual (normalizado)')
plt.legend()
plt.show()
# Out:
# 🔎 R² Score del modelo: 0.0086
